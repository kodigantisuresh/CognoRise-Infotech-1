# %% [markdown]
# ## Forecasting Iris Species using Machine Learning
# Using the sepal and petal lengths, we will construct a machine learning experiment in this notebook with the aim of identifying the species of iris flower. This kind of issue is referred to as a regression and classification problem because we're attempting to forecast the species of the flower.
# Finally, I have developed a machine learning model that can identify the Iris Species using measurements of the flower's sepal and petal lengths.

# %% [markdown]
# # Problem Definition
# Examining our ability to accurately estimate the species of Iris flower from the provided metrics for the Iris datset

# %% [markdown]
# # Data
# Based on the Iris data, we may classify it as a Regression problem that requires a prediction.

# %% [markdown]
# # Evaluation
# As a result of this issue. The goal, like with many regression evaluations, will be to obtain the highest accuracy value feasible.

# %% [markdown]
# # Features
# Features are various components of data.
# The first step is to import the data and explore it. And creating a Decision tree model is our main objective.

# %% [markdown]
# # Importing the required packages and modules.

# %%
# import the basic libaries 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read the iris data set 
iris = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Data Science Internship\IRIS.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
len(iris)
# Out:
# 150

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Exploratory Data Analysis(EDA)
# - Data Cleaning : handling missing values or outliers
# - Data Analyssis & Visualization

# %%
# checking null values 
iris.isna().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Lable_Encoding the complete iris dataset 
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()
iris['species']= label_encoder.fit_transform(iris['species'])

# %%
sns.pairplot(iris)

# %%
plt.hist(iris)
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0., 11., 48., 49., 31., 11.],
#         [ 0.,  0.,  8., 87., 51.,  4.,  0.,  0.,  0.,  0.],
#         [ 0., 37., 13.,  1., 10., 34., 30., 20.,  5.,  0.],
#         [50., 48., 46.,  6.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [50., 50., 50.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.  , 0.79, 1.58, 2.37, 3.16, 3.95, 4.74, 5.53, 6.32, 7.11, 7.9 ]),
#  <a list of 5 BarContainer objects>)

# %%
sns.lineplot(iris)
# Out:
# <Axes: >

# %%
iris.shape
# Out:
# (150, 5)

# %%
# iris.drop(columns=["Id"])

# %%
x=iris.iloc[:,1:5]
y=iris['species']

# %%
x
# Out:
#      sepal_width  petal_length  petal_width  species
# 0            3.5           1.4          0.2        0
# 1            3.0           1.4          0.2        0
# 2            3.2           1.3          0.2        0
# 3            3.1           1.5          0.2        0
# 4            3.6           1.4          0.2        0
# ..           ...           ...          ...      ...
# 145          3.0           5.2          2.3        2
# 146          2.5           5.0          1.9        2
# 147          3.0           5.2          2.0        2
# 148          3.4           5.4          2.3        2
# 149          3.0           5.1          1.8        2
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int32

# %%
iris['species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris.species.value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
colnames = list(iris.columns)
print(colnames)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %% [markdown]
# ## Spliting the Data into Train & Test

# %%
from sklearn.model_selection import train_test_split
# split the data into train and test 
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      sepal_width  petal_length  petal_width  species
# 22           3.6           1.0          0.2        0
# 15           4.4           1.5          0.4        0
# 65           3.1           4.4          1.4        1
# 11           3.4           1.6          0.2        0
# 42           3.2           1.3          0.2        0
# ..           ...           ...          ...      ...
# 71           2.8           4.0          1.3        1
# 106          2.5           4.5          1.7        2
# 14           4.0           1.2          0.2        0
# 92           2.6           4.0          1.2        1
# 102          3.0           5.9          2.1        2
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_width  petal_length  petal_width  species
# 73           2.8           4.7          1.2        1
# 18           3.8           1.7          0.3        0
# 118          2.6           6.9          2.3        2
# 78           2.9           4.5          1.5        1
# 76           2.8           4.8          1.4        1
# 31           3.4           1.5          0.4        0
# 64           2.9           3.6          1.3        1
# 141          3.1           5.1          2.3        2
# 68           2.2           4.5          1.5        1
# 82           2.7           3.9          1.2        1
# 110          3.2           5.1          2.0        2
# 12           3.0           1.4          0.1        0
# 36           3.5           1.3          0.2        0
# 9            3.1           1.5          0.1        0
# 19           3.8           1.5          0.3        0
# 56           3.3           4.7          1.6        1
# 104          3.0           5.8          2.2        2
# 69           2.5           3.9          1.1        1
# 55           2.8           4.5          1.3        1
# 132          2.8           5.6          2.2        2
# 29           3.2           1.6          0.2        0
# 127          3.0           4.9          1.8        2
# 26           3.4           1.6          0.4        0
# 128          2.8           5.6          2.1        2
# 131          3.8           6.4          2.0        2
# 145          3.0           5.2          2.3        2
# 108          2.5           5.8          1.8        2
# 143          3.2           5.9          2.3        2
# 45           3.0           1.4          0.3        0
# 30           3.1           1.6          0.2        0

# %%
# Preprocessing the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## Decission Tree Classification model
# - Building Decision Tree Classifier using Entropy Criteria

# %%
from sklearn.tree import  DecisionTreeClassifier
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %% [markdown]
# ## Ploting the Decission Tree

# %%
#PLot the decision tree
from sklearn import tree
tree.plot_tree(model);

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (2,2), dpi=300)
tree.plot_tree(model,
               feature_names = fn, 
               class_names=cn,
               filled = True);

# %%
text = tree.export_text(model,max_depth=5)  
print(text)
# Out:
# |--- feature_2 <= -0.51
# |   |--- class: 0
# |--- feature_2 >  -0.51
# |   |--- feature_3 <= 0.63
# |   |   |--- class: 1
# |   |--- feature_3 >  0.63
# |   |   |--- class: 2

# %%
model.feature_importances_
# Out:
# array([0.        , 0.        , 0.57949007, 0.42050993])

# %%
import pandas as pd
feature_imp = pd.Series(model.feature_importances_,index=fn).sort_values(ascending=False) 
feature_imp
# Out:
# petal length (cm)    0.57949
# petal width (cm)     0.42051
# sepal length (cm)    0.00000
# sepal width (cm)     0.00000
# dtype: float64

# %%
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %%
#Predicting on test data
# predicting on test data set 
y_pred = model.predict(x_test_scaled) 
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
# getting the count of each category
pd.Series(y_pred).value_counts()
# Out:
# 2    11
# 0    10
# 1     9
# dtype: int64

# %%
# getting the 2 way table to understand the correct and wrong predictions
pd.crosstab(y_test,y_pred)
# Out:
# col_0     0  1   2
# species
# 0        10  0   0
# 1         0  9   0
# 2         0  0  11

# %%
# Accuracy 
np.mean(y_pred==y_test)
# Out:
# 1.0

# %%
# Classification matrices 
from sklearn.metrics import classification_report
cfr = classification_report
cfr
# Out:
# <function sklearn.metrics._classification.classification_report(y_true, y_pred, *, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=False, zero_division='warn')>

# %%
print(cfr(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ## Building Decision Tree Classifier (CART) using Gini Criteria

# %%
from sklearn.tree import DecisionTreeClassifier
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=5) 
model_gini.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
#Prediction and computing the accuracy
y_preds=model.predict(x_test_scaled)
np.mean(y_preds==y_test)
# Out:
# 1.0

# %%
model.feature_importances_
# Out:
# array([0.        , 0.        , 0.57949007, 0.42050993])

# %%
# Classification matrices 
from sklearn.metrics import classification_report
cfr = classification_report
cfr
# Out:
# <function sklearn.metrics._classification.classification_report(y_true, y_pred, *, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=False, zero_division='warn')>

# %%
print(cfr(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ## Decision Tree Regression Example

# %%
# Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

# %%
array = iris.values
X = array[:,0:3] 
y = array[:,3]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Preprocessing the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = DecisionTreeRegressor(max_depth = 5)
model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %% [markdown]
# ## Testing R_squared value

# %%
from sklearn.metrics import r2_score
r_squared = model.score(X_test_scaled, y_test)
print("R-squared value:", r_squared)

y_pred = model.predict(X_test_scaled)
r_squared = r2_score(y_test, y_pred)
print("R-squared value (alternative method):", r_squared)
# Out:
# R-squared value: 0.9365197089098628
# R-squared value (alternative method): 0.9365197089098628

# %% [markdown]
# ## Training R_squared value

# %%
#Find the training accuracy
model.score(X_train, y_train)
# Out:
# 0.970790878545494

# %%
r_squared = model.score(X_train_scaled, y_train)
print("R-squared value:", r_squared)
# Out:
# R-squared value: 0.970790878545494
